# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import hashlib

# %%
m = hashlib.md5()

# %%
m.update('abc'.encode())

# %%
m.hexdigest()
# Out:
# '900150983cd24fb0d6963f7d28e17f72'

# %%
m.update('abc'.encode())

# %%
m.hexdigest()
# Out:
# '440ac85892ca43ad26d44c7ad9d47d3e'

# %%
m = hashlib.md5()

# %%
m.update('abcabc'.encode())

# %%
m.hexdigest()
# Out:
# '440ac85892ca43ad26d44c7ad9d47d3e'

# %%
'qerwqwqer$440ac85892ca43ad26d44c7ad9d47d3e'

# salt = qerwqwqer # 随机数
# m.update('123' + salt)
# digest = 440ac85892ca43ad26d44c7ad9d47d3e
# password = salt + '$' + digest
# Out:
# 'qerwqwqer$440ac85892ca43ad26d44c7ad9d47d3e'

# %%
import os

# %%
os.urandom(5)
# Out:
# b'\xb3\x9aM\xf1w'

# %%
os.urandom(8)
# Out:
# b'[\x1e\x83\x8dZ\xf0\x89\xe1'

# %%
import base64

# %%
base64.b64encode(os.urandom(8))
# Out:
# b'w8dwNnREHV0='

# %%
salt = base64.b64encode(os.urandom(8))

# %%
m = hashlib.md5()

# %%
password=  '123'

# %%
salt + password.encode()
# Out:
# b'oZ7/gGKayu0=123'

# %%
m.update(salt + password.encode())

# %%
m.hexdigest()
# Out:
# '14f20a006033033b3d7bcdbce7379efe'

# %%
salt.decode() + '$' + m.hexdigest()
# Out:
# 'oZ7/gGKayu0=$14f20a006033033b3d7bcdbce7379efe'
